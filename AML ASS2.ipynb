# %% [markdown]
# # Omphemetse Mangope
# Student No: 201532614
# Advanced Machine Learning
# Assignment 2

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("weightdataset.csv", sep=';')

# %%
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
height = data['Height']
weight = data['Weight']

# %% [markdown]
# # Visualizing the dataset

# %%
plt.figure(figsize=(14,6))
plt.plot(weight,height,'.')
plt.title('Weight and height scatter ', color='red')
plt.xlabel('weight',color='blue')
plt.ylabel('height',color='blue')
plt.show()

# %%
Epochs = 100
learning_rate = 0.01
n= len(weight)

theta = np.random.rand(2) #Specifying theta parameters


def gradient_descent(weight,height,theta,Epochs,learning_rate): # Gradient descent function
    
    past_cost = [] 
    past_theta = [theta]
    
    for i in range(Epochs):
        
        linear_model = theta[0] + theta[1] * weight # linear regression
        cost = 1/(2*n) * sum((prediction - height)**2) # Cost function
        past_cost.append(cost)
        
        theta[0] = theta[0] - (learning_rate*1/(n) * sum(prediction - height)) # derivative for theta_0
        theta[1] = theta[1] - (learning_rate*1/(n) * sum(prediction - height))*weight # derivative for theta_1
        past_theta.append(theta)
        
    return(past_cost,past_theta)

# %%
past_cost,past_theta = cost_function(weight,height,theta,Epochs,learning_rate)
theta = past_theta[-1]

# %% [markdown]
# # Plot of the Cost Function

# %%
plt.figure(figsize=(15,6))
plt.title('Cost Function')
plt.xlabel('number of iterations')
plt.ylabel('cost')
plt.plot(past_cost,'r-')
plt.show()

# %%
print('Gradient Descent:{:.2f},{:.2f}'.format(theta[0] , theta[1]))
# Out:
# Gradient Descent:0.06,0.41

# %% [markdown]
# # Prediction using the regression line

# %%
linear_model = theta[0] + theta[1] * weight

plt.figure(figsize=(20,8))
plt.plot(weight,height,'.')
plt.plot(weight,linear_model,label='Regression line: height=θ_0 + θ_1*weight')
plt.xlabel('weights')
plt.ylabel('heights')
plt.title('Model parameters={:.2f},{:.2f}'.format(theta[0],theta[1]))
plt.legend(loc=4)
plt.show()
